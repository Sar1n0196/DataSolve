# %%
import pandas as pd
import numpy as np
import ast

# %%
df = pd.read_csv('train.csv', index_col=0)
df.head(10)
# Out:
#                                                     name  \
# id
# 22474  Information Regarding the Merger of Navios Mar...
# 27460  Announcement on Approving the Change of Member...
# 6926           SFC Suspends Shiu Yau Wah for Five Months
# 6982             Renminbi RMB Haircut - February 4, 2020
# 5022   Anti-Money Laundering, Countering Financing of...
# 13725  Order Approving Proposed Rule Change Relating ...
# 30296  Adjudication Order In Respect of PRB Securitie...
# 14814  “Sustainable Finance: The Changing Regulatory ...
# 17120  Amendments to the General Regulation Under the...
# 36610  Consumer Protection Airlines Commit To Timely ...
#
#                                            document_text  \
# id
# 22474  At a special meeting held on March 24, 2021 sh...
# 27460  On April 2, 2021, the China Financial Futures ...
# 6926   The Securities and Futures Commission (SFC) ha...
# 6982   Pursuant to Section 2.6.2 of the Clearing Hous...
# ...

# %%
df.cat_name.value_counts()
# Out:
# Examinations                                1742
# Securities Sales                            1737
# Market Risk                                 1633
# Regulatory Actions                          1621
# Compliance Management                       1391
# Information Filing                          1387
# Legal Proceedings                           1343
# Fees and Charges                            1301
# Exemptions                                  1190
# Financial Crime                             1178
# Contract Provisions                         1153
# Securities Clearing                         1141
# Listing                                     1124
# Securities Issuing                          1107
# Payments and Settlements                    1099
# Natural Disasters                           1079
# Banking                                     1078
# Regulatory Reporting                        1042
# Licensing                                    999
# ...

# %%
y = pd.get_dummies(df['cat_name'], prefix ='label')
y
# Out:
#        label_Accounting and Finance  label_Antitrust  label_Banking  \
# id
# 22474                             0                0              0
# 27460                             0                0              0
# 6926                              0                1              0
# 6982                              0                0              0
# 5022                              0                0              0
# ...                             ...              ...            ...
# 14825                             0                0              0
# 6875                              0                0              0
# 8901                              0                0              0
# 6285                              0                0              0
# 16675                             0                0              0
#
#        label_Broker Dealer  label_Commodities Trading  \
# id
# 22474                    0                          0
# ...

# %%
label = list(y.columns)
label
# Out:
# ['label_Accounting and Finance',
#  'label_Antitrust',
#  'label_Banking',
#  'label_Broker Dealer',
#  'label_Commodities Trading',
#  'label_Compliance Management',
#  'label_Consumer protection',
#  'label_Contract Provisions',
#  'label_Corporate Communications',
#  'label_Corporate Governance',
#  'label_Definitions',
#  'label_Delivery',
#  'label_Examinations',
#  'label_Exemptions',
#  'label_Fees and Charges',
#  'label_Financial Accounting',
#  'label_Financial Crime',
#  'label_Forms',
#  'label_Fraud',
#  'label_IT Risk',
#  'label_Information Filing',
#  'label_Insurance',
#  'label_Legal',
#  'label_Legal Proceedings',
#  'label_Licensing',
#  'label_Licensure and certification',
#  'label_Liquidity Risk',
#  'label_Listing',
#  'label_Market Abuse',
#  'label_Market Risk',
#  'label_Monetary and Economic Policy',
#  'label_Money Services',
#  'label_Money-Laundering and Terrorist Financing',
#  'label_Natural Disasters',
#  'label_Payments and Settlements',
# ...
